# %% [markdown]
# **Suppose we have a list of cities**

# %%
cities = ['New York','London','Mumbai','Berlin','Sydney','Beijing','Singapore','Chicago','Paris','Johannesburg']

# %% [markdown]
# **and their population density of last three years**

# %%
population_2019=[28.5,31,29,22.7,'-',20.9,33,29,23.95,19]

population_2020=['27','32.1','29','24.33','27.55','24','33.4','30','23','22']

population_2021=[29,31.9,30,26,24.77,22,35,33.77,26.3,'NA']

# %% [markdown]
# **Question 1:** Find the total no of cities we have in the list

# %% [markdown]
# **Question 2:** Change the datatype of population_2020 in appropriate way

# %% [markdown]
# **Question 3:** Check the no of values of population list are same as cities list or not

# %% [markdown]
# **Question 4:** Check there have any null value or not if exists then find the index of null value and change it with 0

# %% [markdown]
# **Question 5:** Create a list of avg population of these three years

# %% [markdown]
# **Question 6:** Round up the values of avg population upto 2 decimals

# %% [markdown]
# **Question 7:** Create a dictionary with list of cities and avg population

# %%
#1
len(cities)
# Out:
# 10

# %%
#2
for i in range(len(population_2020)):
    population_2020[i]=float(population_2020[i])
population_2020
# Out:
# [27.0, 32.1, 29.0, 24.33, 27.55, 24.0, 33.4, 30.0, 23.0, 22.0]

# %%
#2.1
for i in range(len(population_2019)):
    population_2019[i]=float(population_2019[i])
population_2019
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c36753413e81> in <module>()
#       1 #2.1
#       2 for i in range(len(population_2019)):
# ----> 3     population_2019[i]=float(population_2019[i])
#       4 population_2019
#
# ValueError: could not convert string to float: '-'

# %%
#3
print(len(cities))
print(len(population_2019))
print(len(population_2020))
print(len(population_2021))
# Out:
# 10
# 10
# 10
# 10

# %%
#4
x=population_2019.index('-')
y=population_2021.index('NA')
print(x)
print(y)
# Out:
# 4
# 9

# %%
#4
population_2019[4]=0
population_2021[9]=0
print(population_2019)
print(population_2021)
# Out:
# [28.5, 31, 29, 22.7, 0, 20.9, 33, 29, 23.95, 19]
# [29, 31.9, 30, 26, 24.77, 22, 35, 33.77, 26.3, 0]

# %%
#5
avg_population=[]
for i in range(10):
    x=(population_2021[i]+population_2019[i]+population_2020[i])/3
    avg_population.append(x)
avg_population
# Out:
# [28.166666666666668,
#  31.666666666666668,
#  29.333333333333332,
#  24.343333333333334,
#  17.44,
#  22.3,
#  33.800000000000004,
#  30.923333333333336,
#  24.416666666666668,
#  13.666666666666666]

# %%
#6
for i in range(len(avg_population)):
    avg_population[i]=round(avg_population[i],2)
avg_population
# Out:
# [28.17, 31.67, 29.33, 24.34, 17.44, 22.3, 33.8, 30.92, 24.42, 13.67]

# %%
#7
city_population={cities[i]:avg_population[i] for i in range(len(cities))}
city_population
# Out:
# {'New York': 28.17,
#  'London': 31.67,
#  'Mumbai': 29.33,
#  'Berlin': 24.34,
#  'Sydney': 17.44,
#  'Beijing': 22.3,
#  'Singapore': 33.8,
#  'Chicago': 30.92,
#  'Paris': 24.42,
#  'Johannesburg': 13.67}
