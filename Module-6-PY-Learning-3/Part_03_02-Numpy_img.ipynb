# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# !pip install pillow

# %%
img=np.array(Image.open('sample_img.jpg'))
plt.figure(figsize=((8,8)))
plt.imshow(img)

# %%
img
# Out:
# array([[[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        [[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        [[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        ...,
#
#        [[ 72,  66,  66],
#         [ 72,  66,  66],
#         [ 73,  68,  65],
#         ...,
#         [168, 137,  80],
#         [171, 140,  85],
#         [173, 142,  87]],
#
#        [[ 75,  69,  69],
#         [ 74,  68,  68],
#         [ 74,  69,  66],
#         ...,
#         [174, 141,  87],
#         [177, 144,  91],
#         [179, 146,  93]],
#
#        [[ 74,  68,  68],
#         [ 74,  68,  68],
#         [ 75,  70,  67],
#         ...,
#         [177, 144,  90],
#         [180, 147,  94],
#         [183, 150,  97]]], dtype=uint8)

# %%
img.shape
# Out:
# (2280, 1080, 3)

# %%
img.ndim
# Out:
# 3

# %%
# 1800 500
img[1799,499]
#RGB
# Out:
# array([162, 124,  43], dtype=uint8)

# %%
plt.imshow(np.rot90(img,4))

# %%
img1=255-img
plt.figure(figsize=((9,9)))
plt.imshow(img1)

# %%
img_R,img_G,img_B=img.copy(),img.copy(),img.copy()

# %%
img_R
# Out:
# array([[[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        [[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        [[ 55,  54,  59],
#         [ 55,  54,  59],
#         [ 55,  54,  59],
#         ...,
#         [ 53,  52,  57],
#         [ 53,  52,  57],
#         [ 53,  52,  57]],
#
#        ...,
#
#        [[ 72,  66,  66],
#         [ 72,  66,  66],
#         [ 73,  68,  65],
#         ...,
#         [168, 137,  80],
#         [171, 140,  85],
#         [173, 142,  87]],
#
#        [[ 75,  69,  69],
#         [ 74,  68,  68],
#         [ 74,  69,  66],
#         ...,
#         [174, 141,  87],
#         [177, 144,  91],
#         [179, 146,  93]],
#
#        [[ 74,  68,  68],
#         [ 74,  68,  68],
#         [ 75,  70,  67],
#         ...,
#         [177, 144,  90],
#         [180, 147,  94],
#         [183, 150,  97]]], dtype=uint8)

# %%
img_R[:,:,(1,2)]=0
img_G[:,:,(0,2)]=0
img_B[:,:,(0,1)]=0

# %%
plt.imshow(img_R)

# %%
img_rgb=np.concatenate((img_R,img_G,img_B),axis=1)
plt.imshow(img_rgb)
